# %% [markdown]
# # [作業目標]
#
#
# 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？
#
# 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %% [markdown]
# # 作業

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv')
df1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df2 = pd.read_csv(
    'https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv',
    keep_default_na=True,
    na_values=['na', '--']
)
df2
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
print('上面二個DataFrame 不同之處在於下面新增參數na_values=["na", "--"], 可將DataFrame裡符合na 與-- 皆視為NaN')
# Out:
# 上面二個DataFrame 不同之處在於下面新增參數na_values=["na", "--"], 可將DataFrame裡符合na 與-- 皆視為NaN

# %% [markdown]
# ### 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %%
# 這段requests部份因為有擋爬蟲，因此不使用爬API的方式，改採用人工連進去，並copy json檔另存在此jupyter 的folder
# import requests
# r = requests.get('https://www.dcard.tw/_api/forums')
# response = r.text

data = pd.read_json('dcard.json',encoding="utf-8")
data
# Out:
#                                        id         alias         name  \
# 0    35118bd3-e43f-48df-97d4-9fcafb27930a        ntunhs          國北護
# 1    7f125e07-4460-4ea5-80b5-33f0e9aafa0c   midnightlab        午夜實驗室
# 2    c0ed3f99-ed1c-49a8-b413-ed5e925aafe4   timecapsule         時光膠囊
# 3    cc2164ae-88cd-466d-b11b-19e4b1f6f78c        mother          母親節
# 4    11e8d941-0aad-4960-8348-b27c36270fd1     merryxmas   聖誕CiaoCiao
# ..                                    ...           ...          ...
# 605  8a782569-1b67-4e55-80a1-1dbffa199965      acg_meme       ACG 迷因
# 606  1c3ce4f4-c4c4-4456-b5f7-6e47dd289994  japan_travel         日本旅遊
# 607  e41d0b3e-e73e-49b0-a9c5-f9f2002f94cc  videocreator      影音創作者交流
# 608  8f1e3324-93b2-472c-b795-d4c115e115c2    lesserafim  LE SSERAFIM
# 609  a1518c83-4823-43d3-a02a-5e2ed98643c7        iuaena       IUAENA
#
#                                            description  subscriptionCount  \
# 0    國北護板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、...               7127
# 1    午夜實驗室10/6、10/7即將在華山登場！這裏提供大家交流活動資訊與討論，請大家要遵守 D...               1641
# 2    Dcard 九週年最終章！告別動盪不安的 2020，說好了，2021 我們一起活得更努力！請...               4254
# 3                                Dcard 母親節限定板，告訴媽媽我愛妳！                346
# 4             期間限定開啟！只要是和聖誕節有關的事情，或是和「禮物」有關的東西通通都來分享吧！              17612
# ..                                                 ...                ...
# 605  《ACG迷因板》討論動漫、遊戲相關的迷因，不論是與ACG有關的梗圖梗影，或是以動漫、遊戲的圖...               2541
# 606  歡迎大家多多分享日本相關的旅遊經驗、資訊\n不管是景點、美食、遊程、活動資訊等等\n都請踴躍...               4494
# 607        這裡是屬於影音創作者的看板\n歡迎自由發文交流～\n但發文時記得「切勿」使用卡稱發文！                  4
# 608  2023.01.25 JP 1st SG 'FEARLESS'\n發布文章和留言前請詳閱看板規定！               3386
# 609       💜歡迎來到IUAENA板💜\n請UAENA 們在發文&留言前先詳閱規則哦\n感謝配合❣️                791
#
#      subscribed  notificationType   read                 createdAt  \
# 0         False               NaN  False  2016-05-20T22:15:15.808Z
# 1         False               NaN  False  2016-05-14T19:15:15.698Z
# 2         False               NaN  False  2016-05-14T20:15:15.698Z
# 3         False               NaN  False  2016-05-14T22:15:15.698Z
# 4         False               NaN  False  2016-05-17T00:11:15.741Z
# ..          ...               ...    ...                       ...
# 605       False               NaN  False  2022-10-28T03:52:18.410Z
# 606       False               NaN  False  2022-10-28T06:02:46.886Z
# 607       False               NaN  False  2022-11-01T12:12:19.966Z
# 608       False               NaN  False  2022-11-21T03:04:27.554Z
# 609       False               NaN  False  2022-12-05T06:20:44.874Z
#
#                     updatedAt  ...  isPersonaPage  isFeaturedPage  \
# 0    2022-08-16T03:53:09.054Z  ...          False           False
# 1    2022-08-16T03:53:09.054Z  ...          False           False
# 2    2022-08-16T03:53:09.054Z  ...          False           False
# 3    2022-08-16T03:53:09.054Z  ...          False           False
# 4    2022-08-16T03:53:09.054Z  ...          False           False
# ..                        ...  ...            ...             ...
# 605  2022-10-31T03:40:42.564Z  ...          False           False
# 606  2022-10-31T03:37:29.439Z  ...          False           False
# 607  2022-11-14T01:14:02.054Z  ...          False           False
# 608  2022-11-28T11:33:22.342Z  ...          False           False
# 609  2022-12-09T10:19:58.748Z  ...          False           False
#
#      enablePrivateMessage  restrictIdentityOnComment  enableSelectedPosts  \
# 0                    True                      False                False
# 1                   False                      False                False
# 2                   False                      False                False
# 3                   False                      False                False
# 4                   False                      False                False
# ..                    ...                        ...                  ...
# 605                  True                      False                False
# 606                  True                      False                False
# 607                  True                      False                False
# 608                  True                      False                False
# 609                  True                      False                False
#
#      displaySelectedPostsTab  allowModManageSelectedPosts  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
# ..                       ...                          ...
# 605                    False                        False
# 606                    False                        False
# 607                    False                        False
# 608                    False                        False
# 609                    False                        False
#
#      displayGroupChatEntry enableHintedValidations  enableEditedHistory
# 0                    False                   False                 True
# 1                    False                   False                 True
# 2                    False                   False                 True
# 3                    False                   False                 True
# 4                    False                   False                 True
# ..                     ...                     ...                  ...
# 605                  False                   False                 True
# 606                  False                   False                 True
# 607                  False                   False                 True
# 608                  False                   False                 True
# 609                  False                   False                 True
#
# [610 rows x 46 columns]

# %%
data = data.sort_values(by='subscriptionCount',ascending = False)
data.to_csv('dcard_to_csv.csv')

# %%
data
# Out:
#                                        id                 alias  \
# 224  be1a095b-175e-4523-9e06-66a05d939676               dressup
# 233  06e07db4-c8b5-4dae-851f-e8a8236e770c                  meme
# 373  1ce3ebca-8701-42d5-b14c-076fc629bc8e                   sex
# 228  42851318-b9e2-4a75-8a05-9fe180becefe          relationship
# 230  255fd275-fec2-49d2-8e46-2e1557ffaeb0                  talk
# ..                                    ...                   ...
# 521  a932e2a7-be88-4c56-9ae9-ef4eb009666f  advancedPermission02
# 209  36443e19-9334-42f4-b91e-95e601150f61                 hkacg
# 162  d1377288-8432-4ec0-a539-e1ac6d59362c                   mkc
# 172  9e2ea80f-3342-4533-bb7a-d639e6c517e7               athlete
# 566  13d5bcd0-4003-4903-aca3-a15da482397a           pepethefrog
#
#                  name                                        description  \
# 224                穿搭  穿搭板提供各種服裝搭配、包鞋、飾品配件等相關話題討論。\n歡迎分享自己的日常穿搭，或任何潮流...
# 233                梗圖                                            梗圖=有梗的圖
# 373                西斯  西斯板（Sex）提供男女私密話題分享或性教育等情慾議題討論，若有性方面相關問題也可在此發問。...
# 228                感情  無論是遠距離戀愛、情侶間的有趣互動、分手後的藕斷絲連等...都可以在感情板分享你們的愛情故事...
# 230                閒聊  閒聊板提供各種生活周遭大小事的討論，無論是半夜睡不著想找同好，甚至是戴牙套遇到的困擾等......
# ..                ...                                                ...
# 521  正在測試中的進階權限測試看板02  做為日本最具代表性的藝術風格，浮世繪之美始終讓人深深著迷，不管是19世紀印象派大師，抑或是當...
# 209            港澳 ACG           呢度係比香港澳門既同學仔討論同分享各種動漫、遊戲嘅討論區，發文留言前請先閱讀板規
# 162        馬偕醫護管理專科學校  馬偕醫護管理專科學校板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，...
# 172                選手
# 566               佩佩蛙                                                測試用
#
#      subscriptionCount  subscribed  notificationType   read  \
# 224            1134578       False               NaN  False
# 233            1041706       False               NaN  False
# 373             987592       False               NaN  False
# 228             928054       False               NaN  False
# 230             920474       False               NaN  False
# ..                 ...         ...               ...    ...
# 521                  0       False               NaN  False
# 209                  0       False               NaN  False
# 162                  0       False               NaN  False
# 172                  0       False               NaN  False
# 566                  0       False               NaN  False
#
#                     createdAt                 updatedAt  ...  isPersonaPage  \
# 224  2020-02-04T07:28:03.573Z  2022-08-16T03:53:09.054Z  ...          False
# 233  2020-02-04T07:29:33.573Z  2022-09-27T13:56:24.878Z  ...          False
# 373  2020-02-04T07:52:53.573Z  2022-10-27T10:18:27.746Z  ...          False
# 228  2020-02-04T07:28:43.573Z  2022-08-16T03:53:09.054Z  ...          False
# 230  2020-02-04T07:29:03.573Z  2022-08-16T03:53:09.054Z  ...          False
# ..                        ...                       ...  ...            ...
# 521  2021-08-18T08:43:00.111Z  2022-08-16T03:53:09.054Z  ...          False
# 209  2020-01-02T03:23:17.450Z  2022-08-16T03:53:09.054Z  ...          False
# 162  2016-09-23T09:35:46.370Z  2022-08-16T03:53:09.054Z  ...          False
# 172  2017-08-22T05:22:03.771Z  2022-08-16T03:53:09.054Z  ...          False
# 566  2022-02-18T03:15:00.751Z  2022-08-16T03:53:09.054Z  ...          False
#
#      isFeaturedPage  enablePrivateMessage  restrictIdentityOnComment  \
# 224           False                  True                      False
# 233           False                  True                      False
# 373           False                 False                      False
# 228           False                 False                      False
# 230           False                 False                      False
# ..              ...                   ...                        ...
# 521           False                 False                      False
# 209           False                  True                      False
# 162           False                  True                      False
# 172           False                 False                      False
# 566           False                 False                      False
#
#      enableSelectedPosts  displaySelectedPostsTab  \
# 224                 True                     True
# 233                False                    False
# 373                False                    False
# 228                False                    False
# 230                False                    False
# ..                   ...                      ...
# 521                False                    False
# 209                False                    False
# 162                False                    False
# 172                False                    False
# 566                False                    False
#
#      allowModManageSelectedPosts  displayGroupChatEntry  \
# 224                         True                  False
# 233                        False                  False
# 373                        False                  False
# 228                        False                  False
# 230                        False                  False
# ..                           ...                    ...
# 521                        False                  False
# 209                        False                  False
# 162                        False                  False
# 172                        False                  False
# 566                        False                  False
#
#     enableHintedValidations  enableEditedHistory
# 224                   False                 True
# 233                   False                 True
# 373                   False                 True
# 228                   False                 True
# 230                   False                 True
# ..                      ...                  ...
# 521                   False                 True
# 209                   False                 True
# 162                   False                 True
# 172                   False                 True
# 566                   False                 True
#
# [610 rows x 46 columns]
